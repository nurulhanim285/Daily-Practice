# %% [markdown]
# - Data Visualization is small part of the overall EDA process
#
# - EDA - Exploratory Data Analysis
#
# - Data Science - Data Analysis --->
#
# - Data Analysts --->
#     - tools like Power BI
#     - Tableau
#     - Large volumes of data - large quantity
#         - 300 rows is not large
#         - 10K arounf data fair amount of data
#         - 400K rows of data
#
# - To be able to find data - data sources
#
# - import that data into your python files (1)
#
# - should be able to analyse it (2)
#     - by using visualization tools we learnt
#     - matplotlib and seaborn

# %% [markdown]
# 1. Find data related to the titanic ship
#     - download it
#     - import to nbs
#     - make some visualizations
#     - and finally, write 4 lines about the data (give some infromation about the data that is not easily observable -make some judgements/inferences)

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
# Load Titanic dataset from seaborn
titanic = sns.load_dataset("titanic")

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.to_csv("data/phase_1_titanic_dataset.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.to_csv("data/phase_1_titanic_dataset.csv",index=False)
#
# AttributeError: module 'seaborn' has no attribute 'to_csv'

# %%
titanic = titanic.dropna()

# %%
titanic['age']=titanic['age'].astype('int')

titanic
# Out:
# C:\Users\Hanim\AppData\Local\Temp\ipykernel_16904\2498788022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['age']=titanic['age'].astype('int')
#      survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 1           1       1  female   38      1      0  71.2833        C  First
# 3           1       1  female   35      1      0  53.1000        S  First
# 6           0       1    male   54      0      0  51.8625        S  First
# 10          1       3  female    4      1      1  16.7000        S  Third
# 11          1       1  female   58      0      0  26.5500        S  First
# ..        ...     ...     ...  ...    ...    ...      ...      ...    ...
# ...

# %%
titanic['fare']=titanic['fare'].astype('int')

titanic.head()
# Out:
# C:\Users\Hanim\AppData\Local\Temp\ipykernel_16904\47454373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['fare']=titanic['fare'].astype('int')
#     survived  pclass     sex  age  sibsp  parch  fare embarked  class    who  \
# 1          1       1  female   38      1      0    71        C  First  woman
# 3          1       1  female   35      1      0    53        S  First  woman
# 6          0       1    male   54      0      0    51        S  First    man
# 10         1       3  female    4      1      1    16        S  Third  child
# 11         1       1  female   58      0      0    26        S  First  woman
#
#     adult_male deck  embark_town alive  alone
# 1        False    C    Cherbourg   yes  False
# ...

# %% [markdown]
# 1. Mostly the survived passanger from deck C
# 2. Mostly of them are from first class.
# 3. Age of the survival are 38,35,47,56,19,26, and most of them are women.
# 4. The ticket fare range in between 16 to 71.

# %%
import matplotlib.pyplot as plt

sex= titanic['sex']
age= titanic['age']

# create a bar plot
plt.scatter(sex,age, color = 'green') # specify properties of our bar chart 
plt.title('Chart of Age vs Sex')
plt.xlabel('sex')
plt.ylabel('age')
plt.show() #you might need this

# %% [markdown]
# https://data.gov.my/data-catalogue/air_pollution
#
# Problem
# Air Pollution
#
# who?
#
# Malaysian citizen
#
# Where?
# across malaysia
#
# why?
#
# less air pollution action can be take

# %%
import pandas as pd

airpollution=pd.read_csv("air_pollution.csv")
airpollution.info()
airpollution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   432 non-null    int64
#  1   Unnamed: 0     432 non-null    int64
#  2   date           432 non-null    object
#  3   pollutant      432 non-null    object
#  4   concentration  410 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 17.0+ KB
#      Unnamed: 0.1  Unnamed: 0        date pollutant  concentration
# 0               0           0  2017-01-01        CO         0.5610
# 1               1           1  2017-02-01        CO         0.5300
# 2               2           2  2017-03-01        CO         0.5890
# 3               3           3  2017-04-01        CO         0.6620
# 4               4           4  2017-05-01        CO            NaN
# ..            ...         ...         ...       ...            ...
# ...

# %%
df.shape
# Out:
# (432, 4)

# %%
df.to_csv('air_pollution.csv')

# %%
airpollution
# Out:
#      Unnamed: 0.1  Unnamed: 0        date pollutant  concentration
# 0               0           0  2017-01-01        CO         0.5610
# 1               1           1  2017-02-01        CO         0.5300
# 2               2           2  2017-03-01        CO         0.5890
# 3               3           3  2017-04-01        CO         0.6620
# 4               4           4  2017-05-01        CO            NaN
# ..            ...         ...         ...       ...            ...
# 427           427         427  2022-08-01       SO2         0.0012
# 428           428         428  2022-09-01       SO2         0.0012
# 429           429         429  2022-10-01       SO2         0.0012
# 430           430         430  2022-11-01       SO2         0.0012
# 431           431         431  2022-12-01       SO2         0.0013
#
# [432 rows x 5 columns]

# %%
df['pollutant']= df['pollutant']

# %%
df.head()
# Out:
#    Unnamed: 0        date pollutant  concentration
# 0           0  2017-01-01        CO          0.561
# 1           1  2017-02-01        CO          0.530
# 2           2  2017-03-01        CO          0.589
# 3           3  2017-04-01        CO          0.662
# 4           4  2017-05-01        CO            NaN

# %%
sns.pairplot(airpollution,hue='pollutant')

# %% [markdown]
# 1. The type of air pollutant
#     *'CO',
#     *'NO²',
#     *'O³',
#     *'PM₁₀',
#     * 'PM₂.₅',
#     *'SO²'.
#
# 2. The concentration of the pollutant in parts per million (ppm) or micrograms per cubic meter (µg/m³).
#
# Higher concentration in the air were PM 10 & PM2.5

# %%
sns.pairplot(airpollution,hue='concentration')

# %%
df

# %%
x = np.random.randint(1,10,(50,))
x
# Out:
# array([8, 8, 1, 4, 8, 9, 6, 1, 4, 3, 3, 5, 9, 9, 7, 4, 6, 1, 3, 2, 2, 3,
#        1, 7, 7, 3, 7, 9, 1, 1, 4, 1, 8, 4, 3, 3, 5, 5, 8, 9, 1, 8, 2, 3,
#        9, 9, 9, 6, 1, 7], dtype=int32)

# %%
#generate a dataset

import numpy as np

a = np.random.randint(5000000,10000000,(10000000,))  #start and stop,size
b = np.random.randint(5000000,10000000,(10000000,))
c = np.random.randint(5000000,10000000,(10000000,))
d = np.random.randint(5000000,10000000,(10000000,))

# %%
import pandas as pd

population = {
    'KL':a,
    'Jb':b,
    'SG':c,
    'PJ':d
}
df = pd.DataFrame(population)

df.tail()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   KL      int32
#  1   Jb      int32
#  2   SG      int32
#  3   PJ      int32
# dtypes: int32(4)
# memory usage: 152.6 MB

# %%
df.to_csv('testpopulation.csv')

# %%
import pandas as pd

df = pd.read_csv('iris.csv')
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df['a'][149] #column them exact row #value

df['a']

df[['a','b','f']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Hanim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ...

# %%
x= [[11,22,33],
    [44,55,66]]

x[0][2]
# Out:
# 33

# %%
# this is how you target a row
df.loc[4]  #row

df["a"][8]  #goes first to column, row

df.loc[0:4][['a','f','d']]  #row indexes (mostly intergers) x column (strings)

#slicing
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Hanim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 4
# ...

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
coulmn= ['p_len,'p_vid,'s_wid','species']

iris = pd.read_csv('iris.csv', header= None, skiprows= 1, names= columns)
iris.head(2)
# Out:
#   Cell In[56], line 1
#     coulmn= ['p_len,'p_vid,'s_wid','species']
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
iris.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 iris.shape
#
# NameError: name 'iris' is not defined

# %%
# i want a table of just three columns

#d f a
