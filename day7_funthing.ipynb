# %%
#create one class
# one attribute saves name
#one method welcome (name): return f"Welcome{name}!!!""

#classes

class SelamatDatang:
    name="Hanim"

    def welcome(name):
        return f"Selamat Datang:{name}!!! You are very welcome here!!!"

# %%
SelamatDatang.welcome("Hanim")
# Out:
# 'Selamat Datang:Hanim!!! You are very welcome here!!!'
