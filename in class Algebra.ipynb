# %% [markdown]
# -data-
#
#     - iris: [sepal length,sepal width,species]
#     - titanic: [pclass sibling spouse fare age gender survival]
#     - tips : []
#     - penguins: [species island length] widths

# %% [markdown]
# columns = vectors

# %%
list2 = [3,4,5, 'idrees',4.5, [3,['a','b'],5]]

list2[5][1][0]
# Out:
# 'a'

# %%
vectorx = [3,4,[5,6,7],3]

vectorx[2][1]
# Out:
# 6

# %%
vector1 = [3,4,10]

vector2 = [2,4,10]

vector3 =[30,4,10]

sum(vector1)
len(vector1) # number of element
# Out:
# 3

# %%
import numpy as np

arr = np.array(vector1)
arr

arr.max()
arr.min()
arr.mean()
arr.var() # 8.0
arr.std() # 2.82
# Out:
# np.float64(3.0912061651652345)

# %%
vector1 = [10,4,10]
vector2 = [20,4,10]
vector3 = [30,4,10]

matrix = [vector1, 
          vector2, 
          vector3] # 0 1 2

matrix = [[10,4,10],
          [20,4,10],
          [30,4,10]]

matrix

# how to check the dimensions?

 # [2,4,10] as a result
 # 2 as a result
# Out:
# [[10, 4, 10], [20, 4, 10], [30, 4, 10]]

# %%
matrix = [vector1,vector2,vector3] #0 1 2

matrix
 #[2,4,10] as result
 #2 as result
# Out:
# [[3, 4, 10], [2, 4, 10], [30, 4, 10]]

# %%
matrix2 = [[3,4,10],
           [2,4,10]]

# %%
matrix2[1]
# Out:
# [2, 4, 10]

# %%
matrix2[1][0]
# Out:
# 2

# %%
matrix[0][2]  # row x column
# Out:
# 10

# %%
matrix[0:2][8] # row  x  column
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 matrix[0:2][8] # row  x  column
#
# IndexError: list index out of range

# %%
matrix = [10,4,10], #0
         [20,4,10], #1  #0
         [30,4,10], #2   #1
         [30,4,10]  #3

matrixarr =np.array(matrix)
# Out:
#   Cell In[30], line 2
#     [20,4,10], #1  #0
#     ^
# IndentationError: unexpected indent

# %%
type(matrixarr)

matrixarr.ndim

matrixarr[1][2]

#  1 2
matrixarr[1:3][2] # rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 type(matrixarr)
#       3 matrixarr.ndim
#       5 matrixarr[1][2]
#
# NameError: name 'matrixarr' is not defined

# %%
type(matrix)
# Out:
# list

# %%
matrixarr[1][2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 matrixarr[1][2]
#
# NameError: name 'matrixarr' is not defined

# %%
matrixarr * 2 # scalar multiplication

# scaler operations with arrays
# 

matrixarr.ndim
matrixarr.shape # how many rows and columns

# rows  x  columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 matrixarr * 2 # scalar multiplication
#       3 # scaler operations with arrays
#       4 #
#       6 matrixarr.ndim
#
# NameError: name 'matrixarr' is not defined

# %%
# broadcastinggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggg

matrixarr + 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 # broadcastinggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggg
# ----> 3 matrixarr + 100
#
# NameError: name 'matrixarr' is not defined

# %%
a = np.array([[1, 3, 5, 6],
             [2, 8, 7, 9]]
             )
b = np.array([[10], 
              [100]])

a - b
a * b
a / b
a + b
# Out:
# array([[ 11,  13,  15,  16],
#        [102, 108, 107, 109]])

# %%
variance = np.array([145325, 423542, 24355, 3523456])
n = np.array([145, 542, 355, 3456])

# %%
((variance)**0.5) .round(2)
# Out:
# array([ 381.22,  650.8 ,  156.06, 1877.09])

# %%
covariance = np.array([145325, 423542])

n = np.array([145, 542, 355, 3456])

stdx , stdy = np.array([ 381.22,  650.8])

stdx
stdy


r = covariance/(stdx*stdy)
r
# Out:
# array([0.58575649, 1.70715621])

# %%
x = np.array([[1,4,1],
              [2,5,2]])

w = np.array([10,10,10])

w2 = np.array([[10,2,3],
              [10,2,3],
              [10,2,3]])

matmultiply_xw = np.dot(x,w)
matmultiply_xw
# Out:
# array([60, 90])

# %%
matmultiply_xw2 = np.dot(x,w2)
matmultiply_xw2
# Out:
# array([[60, 12, 18],
#        [90, 18, 27]])

# %%
matmultiply_xw2 = x @ w2
matmultiply_xw2
# Out:
# array([[60, 12, 18],
#        [90, 18, 27]])

# %%
matmultiply_xw2 = np.matmul(x,w2)
matmultiply_xw2
# Out:
# array([[60, 12, 18],
#        [90, 18, 27]])
