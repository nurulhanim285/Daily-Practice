# %% [markdown]
# # import a dataset of your choice from seaborn
# # titanic or tips or penguins
#
# # create bar plot. Make it pretty
# # create a scatterplot
# # create a pairplot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('penguins') # helps us get a dataset?

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# types of data we have in datasets, columns
# catagorical
# numerical data
# A Bar plot:

# %%
sdf = df.groupby("species")['body_mass_g'].mean()
sdf
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
# when to use what

sns.barplot(data = df, x = 'species', y = 'bill_length_mm')
# Out:
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
df.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
df[['bill_length_mm','species']]
# Out:
#      bill_length_mm species
# 0              39.1  Adelie
# 1              39.5  Adelie
# 2              40.3  Adelie
# 3               NaN  Adelie
# 4              36.7  Adelie
# ..              ...     ...
# 339             NaN  Gentoo
# 340            46.8  Gentoo
# 341            50.4  Gentoo
# 342            45.2  Gentoo
# 343            49.9  Gentoo
#
# [344 rows x 2 columns]

# %%
df['species']
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
df2 = df['species'].value_counts()

df2.index
print(df2)

plt.bar(df2.index, df2)
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64
# <BarContainer object of 3 artists>

# %%
plt.bar( df['species'], df['bill_length_mm'] )
# Out:
# <BarContainer object of 344 artists>

# %%
plt.scatter( df['bill_depth_mm'], df['bill_length_mm'] )

# %% [markdown]
# Is to try and understand how one feature, affects the other. How relationships between different columns work.

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.pairplot(df, corner=True, hue='day')

# %%
df.describe().round(2)
# Out:
#        total_bill     tip    size
# count      244.00  244.00  244.00
# mean        19.79    3.00    2.57
# std          8.90    1.38    0.95
# min          3.07    1.00    1.00
# 25%         13.35    2.00    2.00
# 50%         17.80    2.90    2.00
# 75%         24.13    3.56    3.00
# max         50.81   10.00    6.00

# %%
df[['total_bill','tip','size']].cov().round(2)


# --------------------

columns = ['total_bill','tip','size']

covariance = df[columns].cov()

covariance.round(2)
# Out:
#             total_bill   tip  size
# total_bill       79.25  8.32  5.07
# tip               8.32  1.91  0.64
# size              5.07  0.64  0.90

# %% [markdown]
# Covariance Matrix
# total bill vs total bill = 79.25

# %% [markdown]
# Correlation

# %%
corelation = df[columns].corr(method= 'pearson') # corelation matrix 
corelation.round(2)
# Out:
#             total_bill   tip  size
# total_bill        1.00  0.68  0.60
# tip               0.68  1.00  0.49
# size              0.60  0.49  1.00

# %% [markdown]
# if you have some data, like let's say iris data
#
# import it, and tell me about the correlations
#
# Scatterplot shows the correlation
#
# Corelation Heatmap

# %%
sns.heatmap(corelation, cmap= 'rocket', annot=True, fmt=".2f", vmin= 0, vmax=1 )
# Greens coolwarm Blues PiYG
# Out:
# <Axes: >

# %% [markdown]
# Understanding visualisations,
#
# bar plot - matplot, sns
#
# scatterplot pairplot -
#
# relationships between variables - features
#
# covariance and corelation
#
# how two variables are changing wrt each other covariance
#
# using a formula
#
# pearson corelation coeffient - cov/stdx and stdy
#
# heatmaps - most of the times -

# %% [markdown]
# Exercise 1 – Add Tip Percentage
# Create a new column:
# tip_pct = tip / total_bill * 100
# Compute correlation of tip_pct with total_bill and with size.
# Look at the heatmap again. What changed?

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
col1 = df['tip']
col1
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df['tipPct'] = pd.Series([col1*100])

df
# Out:
#      total_bill   tip     sex smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#                                                 tipPct
# 0    0      101.0
# 1      166.0
# 2      350.0
# 3      ...
# 1                                                  NaN
# 2                                                  NaN
# ...

# %%
# tips dataset

df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = sns.load_dataset('penguin')

# %% [markdown]
# #### types of data we have in datasets, columns
#
# - catagorical
# numerical publish_display_data
#
# A bar plot

# %%
df.head()

# %%
# when to use what

sns.barplot(data= df, x = 'species', y = 'bill_length_mm')

# %%
df ['bill_length_mm'].value_counts()

# %%
df['species'].value_counts()

df2.index
print(df2)

# %%
plt.bar(df['species'], df['bill_length_mm'])

# %%
#tips dataset

df = sns.load_dataset('tips')

# %% [markdown]
# Correlation

# %%
covariance.round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 covariance.round(2)
#
# NameError: name 'covariance' is not defined

# %%
correlation = df
