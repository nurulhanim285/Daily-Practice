# %%
#import dataset
#run the methods we learn value count,unique, on species column
#create a new df (iris_without_species) object, WITHOUT THE SPECIES COLUMN
#DF.INFO()

# %%
import pandas as pd

df=pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris_without_species = df.drop("species",axis=1)
iris_without_species.head()

print(iris_without_species)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
species =df['species']
species.head()
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
species1 = df['species']

species1.head()

type(species1)
# Out:
# pandas.core.series.Series

# %%
#instead

species2 = df.drop(['sepal_length','sepal_width','petal_length','petal_width'],axis=1)
species2.head()

type(species2)
# Out:
# pandas.core.frame.DataFrame

# %%
iris_without_species.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# calculated column

sepalx = iris_without_species['sepal_length'] * iris_without_species['sepal_width']

sepalx.head()
# Out:
# 0    17.85
# 1    14.70
# 2    15.04
# 3    14.26
# 4    18.00
# dtype: float64

# %%
iris_without_species.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris_without_species['sepal_area'] = sepalx

iris_without_species.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  sepal_area
# 0           5.1          3.5           1.4          0.2       17.85
# 1           4.9          3.0           1.4          0.2       14.70
# 2           4.7          3.2           1.3          0.2       15.04
# 3           4.6          3.1           1.5          0.2       14.26
# 4           5.0          3.6           1.4          0.2       18.00

# %%
#petal area

petalarea = iris_without_species['petal_length'] * iris_without_species['petal_width']
                                 
petalarea.head()
# Out:
# 0    0.28
# 1    0.28
# 2    0.26
# 3    0.30
# 4    0.28
# dtype: float64

# %%
iris_without_species['petal_area']= petalarea

iris_without_species.head(50)

#only part of iris_without_species value of sepal_area is > 14
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 0            5.1          3.5           1.4          0.2       17.85
# 1            4.9          3.0           1.4          0.2       14.70
# 2            4.7          3.2           1.3          0.2       15.04
# 3            4.6          3.1           1.5          0.2       14.26
# 4            5.0          3.6           1.4          0.2       18.00
# 5            5.4          3.9           1.7          0.4       21.06
# 6            4.6          3.4           1.4          0.3       15.64
# 7            5.0          3.4           1.5          0.2       17.00
# 8            4.4          2.9           1.4          0.2       12.76
# 9            4.9          3.1           1.5          0.1       15.19
# 10           5.4          3.7           1.5          0.2       19.98
# 11           4.8          3.4           1.6          0.2       16.32
# 12           4.8          3.0           1.4          0.1       14.40
# ...

# %%
# filter out partd of dataframes using pandas

largeFlowers = iris_without_species[iris_without_species['sepal_area']>16]

largeFlowers.head(10)

#how many large flowers we have in iris dataset
#how many flowers have a sepal area of exactly 16

largeFlowers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  101 non-null    float64
#  1   sepal_width   101 non-null    float64
#  2   petal_length  101 non-null    float64
#  3   petal_width   101 non-null    float64
#  4   sepal_area    101 non-null    float64
#  5   petal_area    101 non-null    float64
# dtypes: float64(6)
# memory usage: 5.5 KB

# %%
largeFlowers
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 35           5.0          3.2           1.2          0.2        16.0
#
#     petal_area
# 35        0.24

# %%
largeFlowers16 = iris_without_species[iris_without_species['sepal_area'] == 16 ]

largeFlowers16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 35 to 35
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  1 non-null      float64
#  1   sepal_width   1 non-null      float64
#  2   petal_length  1 non-null      float64
#  3   petal_width   1 non-null      float64
#  4   sepal_area    1 non-null      float64
#  5   petal_area    1 non-null      float64
# dtypes: float64(6)
# memory usage: 56.0 bytes

# %%
largeFlowers = iris_without_species[iris_without_species['sepal_area']==16]


largeFlowers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 35 to 35
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  1 non-null      float64
#  1   sepal_width   1 non-null      float64
#  2   petal_length  1 non-null      float64
#  3   petal_width   1 non-null      float64
#  4   sepal_area    1 non-null      float64
#  5   petal_area    1 non-null      float64
# dtypes: float64(6)
# memory usage: 56.0 bytes

# %%
largeFlowers
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 35           5.0          3.2           1.2          0.2        16.0
#
#     petal_area
# 35        0.24

# %%
# sorting values by something

sortedLargeFlowers = largeFlowers.sort_values(by='sepal_area', ascending=False)

sortedLargeFlowers
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 35           5.0          3.2           1.2          0.2        16.0
#
#     petal_area
# 35        0.24

# %%
largeFlowers
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 35           5.0          3.2           1.2          0.2        16.0
#
#     petal_area
# 35        0.24

# %%
largestFlower = sortedLargeFlowers.head(1)
largestFlower
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 35           5.0          3.2           1.2          0.2        16.0
#
#     petal_area
# 35        0.24

# %%
areaoflargestflower = sortedLargeFlowers['sepal_area'].min()
areaoflargestflower
# Out:
# np.float64(16.0)

# %%
areaoflargestflower= largestFlower['sepal_area'].max()
arealargestflower
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 2
#       1 areaoflargestflower= largestFlower['sepal_area'].max()
# ----> 2 arealargestflower
#
# NameError: name 'arealargestflower' is not defined

# %%
largeFlowers =sortedLargeFlower['sepal_area']
x = largeFlowers.head(1)
areaoflargestflower=x[131]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Hanim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 131
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 3
# ...

# %%
type(x)
# Out:
# pandas.core.series.Series
